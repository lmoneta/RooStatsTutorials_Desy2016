// %% [markdown]
// # RooStats Standard  Macros
//
// This notebook shows how to run the Standard RooStats macro
//
// Tutorials we can use  (available in tutorials/roostats directory) are:
// * StandardProfileLikelihoodDemo.C
// * StandardBayesianNumericalDemo.C
// * StandardBayesianMCMCDemo.C
// * StandardHypoTestDemo.C
// * StandardHypoTestInvDemo.C
//
// #### Running the BayesianMCMC Calculator

// %%
.L StandardBayesianNumericalDemo.C
// Out:
// RooFit v3.60 -- Developed by Wouter Verkerke and David Kirkby
//                 Copyright (C) 2000-2013 NIKHEF, University of California & Stanford University
//                 All rights reserved, please read http://roofit.sourceforge.net/license.txt

// %% [markdown]
// #### Common Parameter passed to the macro
//
//
// **StandardBayesianMCMCDemo** ( `filename, workspace, model config, data` )
//
// you can also change some other parameters like the confidenceLevel or the number of points to scan

// %%
confLevel = 0.683; 
numIterations = 1000000; // MCMC iterations (has to be larger than 1000)
intervalType = 1;   // central interval

// %%
StandardBayesianNumericalDemo("CountingModel.root","w","ModelConfig","data");
// Out:
// [#1] INFO:ObjectHandling -- RooWorkspace::import(w) importing RooUniform::prior
// [#1] INFO:Minization --  Including the following contraint terms in minimization: (constraint)
// [#1] INFO:Eval -- BayesianCalculator::GetPosteriorFunction :  nll value 0.942377 poi value = 3
// [#1] INFO:Eval -- BayesianCalculator::GetPosteriorFunction : minimum of NLL vs POI for POI =  2.00006 min NLL = 0.805423
// [#1] INFO:InputArguments -- BayesianCalculator:GetInterval Compute the interval from the posterior cdf
// [#1] INFO:NumericIntegration -- PosteriorCdfFunction - integral of posterior = 0.145971 +/- 1.45741e-10
// [#0] WARNING:Eval -- BayesianCalculator::GetInterval : 123 errors reported in evaluating log-likelihood function
// [#1] INFO:Eval -- BayesianCalculator::GetInterval - found a valid interval : [1.17115 , 4.96575 ]
//
// 68.3% interval on s is : [1.17115, 4.96575]
//
// Drawing plot of posterior function.....
// [#1] INFO:Eval -- BayesianCalculator - scan posterior function in nbins = 20
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.86953, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.32532, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.97829, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.65079, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=8.90409, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.93477, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.66266, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.19852, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.98914, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.82539, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.45204, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=8.90689, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.86953, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.32532, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.97829, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.65079, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=8.90409, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.93477, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.66266, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.19852, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.98914, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.82539, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.45204, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=8.90689, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.86953, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.32532, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.97829, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.65079, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=8.90409, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.93477, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.66266, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.19852, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.98914, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.82539, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.45204, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=8.90689, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.86953, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.32532, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.97829, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.65079, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=8.90409, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.93477, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.66266, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.19852, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.98914, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.82539, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.45204, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=8.90689, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.86953, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.32532, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.97829, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.65079, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=8.90409, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.93477, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.66266, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.19852, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.98914, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.82539, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.45204, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=8.90689, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.86953, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.32532, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.97829, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.65079, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=8.90409, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.93477, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.66266, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.19852, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.98914, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.82539, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.45204, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=8.90689, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.86953, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.32532, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.97829, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.65079, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=8.90409, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.93477, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.66266, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.19852, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.98914, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.82539, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.45204, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=8.90689, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.86953, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.32532, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.97829, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.65079, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=8.90409, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.93477, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.66266, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.19852, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.98914, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.82539, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.45204, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=8.90689, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.86953, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.32532, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.97829, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.65079, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=8.90409, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.93477, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.66266, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.19852, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.98914, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.82539, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.45204, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=8.90689, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.86953, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.32532, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.97829, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.65079, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=8.90409, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.93477, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.66266, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.19852, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.98914, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.82539, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.45204, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=8.90689, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.86953, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.32532, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.97829, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.65079, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=8.90409, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.93477, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.66266, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.19852, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.98914, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.82539, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.45204, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=8.90689, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.86953, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.32532, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.97829, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.65079, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=8.90409, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.93477, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.66266, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.19852, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.98914, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.82539, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.45204, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=8.90689, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.86953, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.32532, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.97829, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.65079, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=8.90409, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.93477, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.66266, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.19852, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.98914, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.82539, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.45204, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=8.90689, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.86953, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.32532, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.97829, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.65079, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=8.90409, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.93477, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.66266, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.19852, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.98914, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.82539, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.45204, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=8.90689, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.86953, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.32532, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.97829, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.65079, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=8.90409, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.93477, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.66266, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.19852, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.98914, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.82539, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.45204, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
// ...
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=8.90689, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.86953, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.32532, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.97829, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.65079, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=8.90409, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.93477, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.66266, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.19852, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.98914, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.82539, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.45204, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=8.90689, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.86953, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.32532, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.97829, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.65079, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=8.90409, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.93477, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.66266, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.19852, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.98914, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.82539, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.45204, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=8.90689, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.86953, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.32532, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.97829, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.65079, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=8.90409, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.93477, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.66266, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.19852, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.98914, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.82539, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.45204, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=8.90689, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.86953, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.32532, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.97829, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.65079, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=8.90409, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.93477, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.66266, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.19852, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.98914, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.82539, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.45204, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=8.90689, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.86953, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.32532, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.97829, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.65079, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=8.90409, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.93477, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.66266, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.19852, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.98914, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.82539, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=9.45204, sigma=sigmab=0.2
// [#0] ERROR:Eval -- RooAbsReal::logEvalError(constraint) evaluation error,
//  origin       : RooGaussian::constraint[ x=b0 mean=b sigma=sigmab ]
//  message      : getLogVal() top-level p.d.f evaluates to zero
//  server values: x=b0=1, mean=b=8.90689, sigma=sigmab=0.2
// Info in <TCanvas::MakeDefCanvas>:  created default TCanvas with name c1

// %%
//StandardBayesianNumericalDemo("CountingModel.root","w","ModelConfig","data");
gPad->Draw();
